# %% [markdown]
# # 수업
# - 1개월: 파이썬 기초 수업
#   - 이미 다른 언어들을 한 번쯤은 다뤄본 경험들이 있기 때문에
#   - 기초 수업은 자바와 비교해서 파이썬의 특징에 대해서만 다루도록 하겠습니다.
#   - 1 ~ 2주 정도면 기초 수업은 완료
#   - 나머지 시간은 기초 알고리즘과 문제푸는 시간으로 대체
#
# - 3개월: 문제풀이
#   - Brute-Force(전부다해보기/완전탐색)
#   - 동적계획법(Dynamic Programming)
#   - 그래프
#   - 시뮬레이션
#
# - [파이썬 공식 홈페이지](http://www.python.org)

# %% [markdown]
# # 파이썬 기초
# - [파이썬 인터프리터의 이해](https://colab.research.google.com/drive/1573eD0EMVBGVN1ewMkw3jaUAsqAxqe3Y?usp=sharing)
# - [파이썬의 제어문과 함수](https://colab.research.google.com/drive/1bWrWbwxXlD9eZes2Znp92Ef34qOpUl2D?usp=sharing)
# - [파이썬의 클래스](https://colab.research.google.com/drive/14GtApz0LnmHvaW4zOJDtYY22-ElTenR2?usp=sharing)
# - [파이썬의 예외처리](https://colab.research.google.com/drive/1EWsGpizDvwyNogqURK3qyd7RZkpJ2i4e?usp=sharing)
